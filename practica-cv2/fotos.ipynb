# %% [markdown]
# 1.-CARGAR IMAGEN BGR

# %%
import cv2
import matplotlib.pyplot as plt

img1=cv2.imread('img1.jpeg')
img2=cv2.imread('img2.jpeg')
img3=cv2.imread('img3.jpeg')
plt.imshow(img1)
plt.show()
plt.imshow(img2)
plt.show()
plt.imshow(img3)
plt.show()

# %% [markdown]
# 2.- MOSTRAR IMAGEN CONVERTIDA A RGB USANDO MATPLOTLIB

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = [4, 4]
img1= cv2.imread('img1.jpeg')
img2= cv2.imread('img2.jpeg')
img3= cv2.imread('img3.jpeg')

img1RGB=cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2RGB=cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
img3RGB=cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)

plt.imshow(img1RGB)
plt.show()
plt.imshow(img2RGB)
plt.show()
plt.imshow(img3RGB)
plt.show()

# %% [markdown]
# 3.-CONVERIR IMAGEN BGR A ESACALA DE GRISES UTILIZANDO CV2.CVTCOLOR

# %%
import cv2
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [8, 4]

img1 = cv2.imread('img1.jpeg', cv2.IMREAD_COLOR)
img1_rgb = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

img2 = cv2.imread('img2.jpeg', cv2.IMREAD_COLOR)
img2_rgb = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

img3 = cv2.imread('img3.jpeg', cv2.IMREAD_COLOR)
img3_rgb = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)

# Visualizar la imagen1 original y sus canales de color
plt.subplot(141)
plt.title("Imagen original")
plt.imshow(img1_rgb)
plt.axis("off")

plt.subplot(142)
plt.title("Canal Rojo")
plt.imshow(img1[:,:,2], cmap='gray')
plt.axis("off")

plt.subplot(143)
plt.title("Canal Verde")
plt.imshow(img1[:,:,1], cmap='gray')
plt.axis("off")

plt.subplot(144)
plt.title("Canal Azul")
plt.imshow(img1[:,:,0], cmap='gray')
plt.axis("off")

plt.show()

# Visualizar la imagen2 original y sus canales de color
plt.subplot(141)
plt.title("Imagen original")
plt.imshow(img2_rgb)
plt.axis("off")

plt.subplot(142)
plt.title("Canal Rojo")
plt.imshow(img2_rgb[:,:,2], cmap='gray')
plt.axis("off")

plt.subplot(143)
plt.title("Canal Verde")
plt.imshow(img2_rgb[:,:,1], cmap='gray')
plt.axis("off")

plt.subplot(144)
plt.title("Canal Azul")
plt.imshow(img2_rgb[:,:,0], cmap='gray')
plt.axis("off")

plt.show()

# Visualizar la imagen3 original y sus canales de color
plt.subplot(141)
plt.title("Imagen original")
plt.imshow(img3_rgb)
plt.axis("off")

plt.subplot(142)
plt.title("Canal Rojo")
plt.imshow(img3_rgb [:,:,2], cmap='gray')
plt.axis("off")

plt.subplot(143)
plt.title("Canal Verde")
plt.imshow(img3_rgb [:,:,1], cmap='gray')
plt.axis("off")

plt.subplot(144)
plt.title("Canal Azul")
plt.imshow(img3_rgb [:,:,0], cmap='gray')
plt.axis("off")

plt.show()

# %% [markdown]
# 4.-GUARDAR LA IMAGEN CONVERTIDA

# %%
#GUARDAR IMAGEN CON OPENCV
cv2.imwrite('imagen_gris1.jpg', img1_rgb[:,:,2])
cv2.imwrite('imagen_gris2.jpg', img2_rgb[:,:,2])
cv2.imwrite('imagen_gris3.jpg', img3_rgb[:,:,2])
# Out:
# True

# %% [markdown]
# 5.-GUARDAR IAMGEN BGR

# %%
plt.imsave('imagen_BGR1.jpg', cv2.cvtColor(img1_rgb, cv2.COLOR_BGR2RGB))
plt.imsave('imagen_BGR2.jpg', cv2.cvtColor(img2_rgb, cv2.COLOR_BGR2RGB))
plt.imsave('imagen_BGR3.jpg', cv2.cvtColor(img3_rgb, cv2.COLOR_BGR2RGB))
